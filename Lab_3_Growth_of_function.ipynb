# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil-prajapti-ops/Aps-lab-/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
import matplotlib.pyplot as plt

# Prob_2: Take another example and write the code that runs in fixed amount of time or hasfixed number of steps of execution no matter what is the size of input has constant time complexity.similar to example-1, also plot the graph (eg. even_odd
def is_even_or_odd(number):

    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

n_values_prob2 = list(range(1, 101))
time_values_prob2 = []

for n in n_values_prob2:

    is_even_or_odd(n)
    time_values_prob2.append(1)

plt.figure()
plt.plot(n_values_prob2, time_values_prob2)
plt.xlabel("Input size n (Magnitude of number)")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
# Prob_3: Take another example and write the code that runs in linear amount of time no matter what is the size of input.

# %%
def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values_prob3 = list(range(1, 101))
time_values_prob3 = []

for n in n_values_prob3:

    data_prob3 = list(range(-n // 2, n // 2))
    count_greater_than_zero(data_prob3)

    time_values_prob3.append(n)

plt.figure()
plt.plot(n_values_prob3, time_values_prob3)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for Counting Elements > 0")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example


def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0

    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps

n_values = list(range(1, 1001, 10))
time_values = []

for n in n_values:

    data = list(range(n))

    if n > 0:
        time_values.append(math.log2(n))
    else:
        time_values.append(0)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (log n)")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search Example)")
plt.grid(True)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.



def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            merged.append(left[left_idx])
            left_idx += 1
        else:
            merged.append(right[right_idx])
            right_idx += 1

    while left_idx < len(left):
        merged.append(left[left_idx])
        left_idx += 1

    while right_idx < len(right):
        merged.append(right[right_idx])
        right_idx += 1
    return merged

n_values = list(range(1, 201, 5))
time_values = []

for n in n_values:

    data = list(range(n, 0, -1))

    start_time = time.time()
    merge_sort(data)
    end_time = time.time()

    if n > 1:
        time_values.append(n * math.log2(n))
    else:
        time_values.append(0)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort Example)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example


def find_all_pairs(data):
    count = 0

    for i in range(len(data)):
        for j in range(len(data)):

            count += 1
    return count

n_values = list(range(1, 151, 5))
time_values = []

for n in n_values:
    data = list(range(n))

    time_values.append(n**2)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n^2)")
plt.title("O(n^2) Polynomial Time Complexity (Finding All Pairs Example)")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example


def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

n_values = list(range(1, 20))
time_values = []

for n in n_values:

    time_values.append(1.618**n)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (c^n)")
plt.title("O(c^n) Exponential Time Complexity (Recursive Fibonacci Example)")
plt.grid(True)
plt.yscale('log')
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure

# %%
n_values = np.linspace(1, 50, 100)
constant_time = np.ones_like(n_values)
log_time = np.log2(n_values)
linear_time = n_values
log_linear_time = n_values * np.log2(n_values)
quadratic_time = n_values**2
exponential_time = 2**n_values
plt.figure(figsize=(12, 8))
plt.plot(n_values, constant_time, label='O(1) Constant', color='purple', linestyle='-')
plt.plot(n_values, log_time, label='O(log n) Logarithmic', color='blue', linestyle='--')
plt.plot(n_values, linear_time, label='O(n) Linear', color='green', linestyle='-')
plt.plot(n_values, log_linear_time, label='O(n log n) Log-Linear', color='orange', linestyle='--')
plt.plot(n_values, quadratic_time, label='O(n^2) Quadratic', color='red', linestyle='-')

plt.plot(n_values[n_values < 15], exponential_time[n_values < 15], label='O(2^n) Exponential', color='brown', linestyle=':')

plt.xlabel("Input Size (n)")
plt.ylabel("Operations / Time")
plt.title("Comparison of Time Complexities")
plt.ylim(0, 1000)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Prob_8: Write a function to perform quick sort and show that it has Log-Linear Time Complexity O(n log n) (average case)

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

n_values = list(range(1, 501, 10))
time_values = []

for n in n_values:

    data = [random.randint(0, n*10) for _ in range(n)]

    if n > 1:
        time_values.append(n * math.log2(n))
    else:
        time_values.append(0)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Average Time Complexity (Quick Sort Example)")
plt.grid(True)
plt.show()
